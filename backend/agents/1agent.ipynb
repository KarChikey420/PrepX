# %%
# %pip install langchain-openai
# %pip install dotenv
# Out:
# Collecting langchain-openai
#   Downloading langchain_openai-1.1.11-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.18 in e:\prepx\venv\lib\site-packages (from langchain-openai) (1.2.20)
# Requirement already satisfied: openai<3.0.0,>=2.26.0 in e:\prepx\venv\lib\site-packages (from langchain-openai) (2.29.0)
# Collecting tiktoken<1.0.0,>=0.7.0 (from langchain-openai)
#   Using cached tiktoken-0.12.0-cp312-cp312-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in e:\prepx\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.18->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in e:\prepx\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.18->langchain-openai) (0.7.22)
# Requirement already satisfied: packaging>=23.2.0 in e:\prepx\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.18->langchain-openai) (26.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in e:\prepx\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.18->langchain-openai) (2.12.5)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in e:\prepx\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.18->langchain-openai) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in e:\prepx\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.18->langchain-openai) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in e:\prepx\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.18->langchain-openai) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in e:\prepx\venv\lib\site-packages (from langchain-core<2.0.0,>=1.2.18->langchain-openai) (0.14.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in e:\prepx\venv\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in e:\prepx\venv\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in e:\prepx\venv\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in e:\prepx\venv\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (0.13.0)
# Requirement already satisfied: sniffio in e:\prepx\venv\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in e:\prepx\venv\lib\site-packages (from openai<3.0.0,>=2.26.0->langchain-openai) (4.67.3)
# Collecting regex>=2022.1.18 (from tiktoken<1.0.0,>=0.7.0->langchain-openai)
#   Downloading regex-2026.2.28-cp312-cp312-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: requests>=2.26.0 in e:\prepx\venv\lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.32.5)
# Requirement already satisfied: idna>=2.8 in e:\prepx\venv\lib\site-packages (from anyio<5,>=3.5.0->openai<3.0.0,>=2.26.0->langchain-openai) (3.11)
# Requirement already satisfied: certifi in e:\prepx\venv\lib\site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=2.26.0->langchain-openai) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in e:\prepx\venv\lib\site-packages (from httpx<1,>=0.23.0->openai<3.0.0,>=2.26.0->langchain-openai) (1.0.9)
# Requirement already satisfied: h11>=0.16 in e:\prepx\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<3.0.0,>=2.26.0->langchain-openai) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in e:\prepx\venv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.18->langchain-openai) (3.1.0)
# Requirement already satisfied: orjson>=3.9.14 in e:\prepx\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.18->langchain-openai) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in e:\prepx\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.18->langchain-openai) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in e:\prepx\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.18->langchain-openai) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in e:\prepx\venv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.18->langchain-openai) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in e:\prepx\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.18->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in e:\prepx\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.18->langchain-openai) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in e:\prepx\venv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<2.0.0,>=1.2.18->langchain-openai) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in e:\prepx\venv\lib\site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\prepx\venv\lib\site-packages (from requests>=2.26.0->tiktoken<1.0.0,>=0.7.0->langchain-openai) (2.6.3)
# Requirement already satisfied: colorama in e:\prepx\venv\lib\site-packages (from tqdm>4->openai<3.0.0,>=2.26.0->langchain-openai) (0.4.6)
# Downloading langchain_openai-1.1.11-py3-none-any.whl (87 kB)
# Using cached tiktoken-0.12.0-cp312-cp312-win_amd64.whl (878 kB)
# Downloading regex-2026.2.28-cp312-cp312-win_amd64.whl (277 kB)
# Installing collected packages: regex, tiktoken, langchain-openai
# Successfully installed langchain-openai-1.1.11 regex-2026.2.28 tiktoken-0.12.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: dotenv in e:\prepx\venv\lib\site-packages (0.9.9)
# Requirement already satisfied: python-dotenv in e:\prepx\venv\lib\site-packages (from dotenv) (1.2.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import os

load_dotenv()

llm = ChatOpenAI(
    model="kimi-k2",   
    openai_api_key=os.getenv("KIMI_API_KEY"),
    openai_api_base="https://api.moonshot.cn/v1",  
)
